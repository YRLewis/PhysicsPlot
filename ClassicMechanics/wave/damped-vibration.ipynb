# %%
import numpy as np
from matplotlib import pyplot as plt

omega0 = 1

def omegar(beta):
    return (omega0**2-beta**2)**0.5
 
plt.figure(figsize=(7,5))
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

beta1 = 0.2
omegar1 = omegar(beta1)
t = np.linspace(0, 30, 150)
plt.plot(t, np.exp(-beta1*t)*(np.cos(omegar1*t)+beta1/omegar1*np.sin(omegar1*t)),label = r'$\Lambda=0.2$')
t1 = np.linspace(0, 30, 30)
plt.plot(t1, np.exp(-beta1*t1)*(1+(beta1/omegar1)**2)**0.5,':')

beta2 = 1
omegar2 = omegar(beta2)
plt.plot(t, np.exp(-beta2*t)*(1+beta2*t),label = r'$\Lambda=1$')



beta3=5
Gamma1 = -beta3+(beta3**2-omega0**2)**0.5
Gamma2 = -beta3-(beta3**2-omega0**2)**0.5
plt.plot(t, (Gamma2*np.exp(Gamma1*t)-Gamma1*np.exp(Gamma2*t))/(Gamma2-Gamma1),label = r'$\Lambda=5$')
plt.yticks([])
plt.xticks([])
plt.xlabel('t')
plt.ylabel('x')
plt.legend()

plt.title(r'Different $\Lambda$ from one position')
plt.show()

# %%
omega0 = 1

def omegar(beta):
    return (omega0**2-beta**2)**0.5
 
plt.figure(figsize=(10,3))

t = np.linspace(0, 300, 10000)


plt.subplot(1, 3, 1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
beta1 = 0.2
omegar1 = omegar(beta1)
x1 = np.exp(-beta1*t)*(np.cos(omegar1*t)+beta1/omegar1*np.sin(omegar1*t))
p1 = -np.exp(-beta1 *t)*(omegar1**2+beta1**2)/omegar1*np.sin(omegar1*t)
plt.plot(x1, p1)
plt.title(r'$\Lambda=0.2$')
ax.arrow(1, 0, 0.2, -0.2,length_includes_head = True,head_width = 0.13, fc='r')

plt.yticks([])
plt.xticks([])
plt.xlabel('x')
plt.ylabel('p')


plt.subplot(1, 3, 2)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
beta2 = 1
x2 = np.exp(-beta2*t)*(1+beta2*t)
y2 = -beta2**2*t*np.exp(-beta2*t)
plt.plot(x2, y2)
plt.title(r'$\Lambda=1$')


ax.arrow(1, 0, 0, -0.15,length_includes_head = True,head_width = 0.09, fc='r')
plt.yticks([])
plt.xticks([])
plt.xlabel('x')
plt.ylabel('p')
plt.xlim(-0.25,1.25)
plt.ylim(-0.5, 0.2)



plt.subplot(1,3,3)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))
beta3=5
Gamma1 = beta3-(beta3**2-omega0**2)**0.5
Gamma2 = beta3+(beta3**2-omega0**2)**0.5
x3 = (Gamma2*np.exp(-Gamma1*t)-Gamma1*np.exp(-Gamma2*t))/(Gamma2-Gamma1)
p3 = (Gamma1*Gamma2)/(Gamma1-Gamma2)*(np.exp(-Gamma1*t)-np.exp(-Gamma2*t))
plt.plot(x3,p3)
plt.title(r'$\Lambda=5$')
plt.xlim(-0.3,1.5)
plt.ylim(-0.15, 0.05)

ax.arrow(1, 0, 0, -0.03,head_width = 0.06, fc='r')
plt.yticks([])
plt.xticks([])
plt.xlabel('x')
plt.ylabel('p')



plt.show()
